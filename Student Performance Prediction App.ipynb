# %% [markdown]
# ### Student Performance Prediction

# %% [markdown]
# Student Performance Prediction App predicts grade of a student by analysing academic and non-academic information of a concerned student
#
#  1. <b>train.csv</b> - Load data to train in this csv file
#  2. <b>pred.csv</b>  - Load data to run prediction in this csv file
#  3. <b>output.csv</b>- Writes predicted output in this file in the column <b>y_pred</b>
#
#  4. <b>TARGET_VARIABLE</b> - Set this variable to name of the feature/column to be predicted
#  5. <b>NUMERICAL_FEATURES</b> - List all feature/column that are of numeric type
#
# <b>Note:</b> Update variables under <b>Variables</b> section to configure inputs if required before running the notebook.
#
# To run notebook cell by cell, click on a cell and click <b>Run</b> button below the <b>Menu</b> bar. Or to run all cells, select <b>Cell --> Run All</b> from Menu bar.

# %% [markdown]
# #### Variables

# %%
TARGET_VARIABLE='G3' #variable to be predicted
NUMERICAL_FEATURES=["age", "G1", "G2"] #features to be interpreted as numeric

# %% [markdown]
# Default values

# %%
INPUT_TRAIN_FILE="train.csv"
INPUT_TEST_FILE="pred.csv"
OUTPUT_PRED_FILE="output.csv"
OUTPUT_PRED="y_pred"
MODEL_FILE="model"

# %% [markdown]
# #### Import library to read file and load to dataframe

# %%
import pandas as pd

# %% [markdown]
# #### Import library to run the app

# %%
import model

# %% [markdown]
# ####  Description of example data loaded
# Attributes for train.csv and test.csv (Portuguese language course) datasets:
#
# 1. school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# 2. sex - student's sex (binary: 'F' - female or 'M' - male)
# 3. age - student's age (numeric: from 15 to 22)
# 4. address - student's home address type (binary: 'U' - urban or 'R' - rural)
# 5. famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 6. Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 7. Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 8. Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 9. Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10. Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 11. reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 12. guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16. schoolsup - extra educational support (binary: yes or no)
# 17. famsup - family educational support (binary: yes or no)
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19. activities - extra-curricular activities (binary: yes or no)
# 20. nursery - attended nursery school (binary: yes or no)
# 21. higher - wants to take higher education (binary: yes or no)
# 22. internet - Internet access at home (binary: yes or no)
# 23. romantic - with a romantic relationship (binary: yes or no)
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related to the course subject, Portuguese:
#
# 31. G1 - first period grade (numeric: from 0 to 20)
# 32. G2 - second period grade (numeric: from 0 to 20)
# 33. G3 - final grade (numeric: from 0 to 20, output target)

# %%
model.train(TARGET_VARIABLE, NUMERICAL_FEATURES)
# Out:
# <style type="text/css">
# #T_346b0_ th {
#   text-align: left;
# }
# #T_346b0_row0_col0, #T_346b0_row0_col2, #T_346b0_row0_col5, #T_346b0_row1_col0, #T_346b0_row1_col1, #T_346b0_row1_col2, #T_346b0_row1_col3, #T_346b0_row1_col4, #T_346b0_row1_col5, #T_346b0_row1_col6, #T_346b0_row2_col0, #T_346b0_row2_col1, #T_346b0_row2_col2, #T_346b0_row2_col3, #T_346b0_row2_col4, #T_346b0_row2_col6, #T_346b0_row3_col0, #T_346b0_row3_col1, #T_346b0_row3_col3, #T_346b0_row3_col4, #T_346b0_row3_col5, #T_346b0_row3_col6, #T_346b0_row4_col0, #T_346b0_row4_col1, #T_346b0_row4_col2, #T_346b0_row4_col3, #T_346b0_row4_col4, #T_346b0_row4_col5, #T_346b0_row4_col6, #T_346b0_row5_col0, #T_346b0_row5_col1, #T_346b0_row5_col2, #T_346b0_row5_col3, #T_346b0_row5_col4, #T_346b0_row5_col5, #T_346b0_row5_col6, #T_346b0_row6_col0, #T_346b0_row6_col1, #T_346b0_row6_col2, #T_346b0_row6_col3, #T_346b0_row6_col4, #T_346b0_row6_col5, #T_346b0_row6_col6, #T_346b0_row7_col0, #T_346b0_row7_col1, #T_346b0_row7_col2, #T_346b0_row7_col3, #T_346b0_row7_col4, #T_346b0_row7_col5, #T_346b0_row7_col6, #T_346b0_row8_col0, #T_346b0_row8_col1, #T_346b0_row8_col2, #T_346b0_row8_col3, #T_346b0_row8_col4, #T_346b0_row8_col5, #T_346b0_row8_col6, #T_346b0_row9_col0, #T_346b0_row9_col1, #T_346b0_row9_col2, #T_346b0_row9_col3, #T_346b0_row9_col4, #T_346b0_row9_col5, #T_346b0_row9_col6, #T_346b0_row10_col0, #T_346b0_row10_col1, #T_346b0_row10_col2, #T_346b0_row10_col3, #T_346b0_row10_col4, #T_346b0_row10_col5, #T_346b0_row10_col6, #T_346b0_row11_col0, #T_346b0_row11_col1, #T_346b0_row11_col2, #T_346b0_row11_col3, #T_346b0_row11_col4, #T_346b0_row11_col5, #T_346b0_row11_col6, #T_346b0_row12_col0, #T_346b0_row12_col1, #T_346b0_row12_col2, #T_346b0_row12_col3, #T_346b0_row12_col4, #T_346b0_row12_col5, #T_346b0_row12_col6, #T_346b0_row13_col0, #T_346b0_row13_col1, #T_346b0_row13_col2, #T_346b0_row13_col3, #T_346b0_row13_col4, #T_346b0_row13_col5, #T_346b0_row13_col6, #T_346b0_row14_col0, #T_346b0_row14_col1, #T_346b0_row14_col2, #T_346b0_row14_col3, #T_346b0_row14_col4, #T_346b0_row14_col5, #T_346b0_row14_col6, #T_346b0_row15_col0, #T_346b0_row15_col1, #T_346b0_row15_col2, #T_346b0_row15_col3, #T_346b0_row15_col4, #T_346b0_row15_col5, #T_346b0_row15_col6, #T_346b0_row16_col0, #T_346b0_row16_col1, #T_346b0_row16_col2, #T_346b0_row16_col3, #T_346b0_row16_col4, #T_346b0_row16_col5, #T_346b0_row16_col6, #T_346b0_row17_col0, #T_346b0_row17_col1, #T_346b0_row17_col2, #T_346b0_row17_col3, #T_346b0_row17_col4, #T_346b0_row17_col5, #T_346b0_row17_col6 {
#   text-align: left;
# }
# #T_346b0_row0_col1, #T_346b0_row0_col3, #T_346b0_row0_col4, #T_346b0_row0_col6, #T_346b0_row2_col5, #T_346b0_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_346b0_row0_col7, #T_346b0_row1_col7, #T_346b0_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_346b0_row2_col7, #T_346b0_row3_col7, #T_346b0_row4_col7, #T_346b0_row5_col7, #T_346b0_row6_col7, #T_346b0_row7_col7, #T_346b0_row8_col7, #T_346b0_row9_col7, #T_346b0_row10_col7, #T_346b0_row11_col7, #T_346b0_row12_col7, #T_346b0_row13_col7, #T_346b0_row14_col7, #T_346b0_row16_col7, #T_346b0_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_346b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_346b0_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_346b0_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_346b0_row0_col1" class="data row0 col1" >0.7910</td>
#       <td id="T_346b0_row0_col2" class="data row0 col2" >1.7043</td>
#       <td id="T_346b0_row0_col3" class="data row0 col3" >1.2120</td>
#       <td id="T_346b0_row0_col4" class="data row0 col4" >0.8501</td>
#       <td id="T_346b0_row0_col5" class="data row0 col5" >0.2423</td>
#       <td id="T_346b0_row0_col6" class="data row0 col6" >0.0582</td>
#       <td id="T_346b0_row0_col7" class="data row0 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_346b0_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_346b0_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_346b0_row1_col1" class="data row1 col1" >0.7948</td>
#       <td id="T_346b0_row1_col2" class="data row1 col2" >1.7407</td>
#       <td id="T_346b0_row1_col3" class="data row1 col3" >1.2257</td>
#       <td id="T_346b0_row1_col4" class="data row1 col4" >0.8450</td>
#       <td id="T_346b0_row1_col5" class="data row1 col5" >0.2376</td>
#       <td id="T_346b0_row1_col6" class="data row1 col6" >0.0593</td>
#       <td id="T_346b0_row1_col7" class="data row1 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_346b0_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_346b0_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_346b0_row2_col1" class="data row2 col1" >0.8525</td>
#       <td id="T_346b0_row2_col2" class="data row2 col2" >1.6576</td>
#       <td id="T_346b0_row2_col3" class="data row2 col3" >1.2268</td>
#       <td id="T_346b0_row2_col4" class="data row2 col4" >0.8430</td>
#       <td id="T_346b0_row2_col5" class="data row2 col5" >0.2163</td>
#       <td id="T_346b0_row2_col6" class="data row2 col6" >0.0665</td>
#       <td id="T_346b0_row2_col7" class="data row2 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_346b0_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_346b0_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_346b0_row3_col1" class="data row3 col1" >0.8670</td>
#       <td id="T_346b0_row3_col2" class="data row3 col2" >1.5766</td>
#       <td id="T_346b0_row3_col3" class="data row3 col3" >1.2337</td>
#       <td id="T_346b0_row3_col4" class="data row3 col4" >0.8359</td>
#       <td id="T_346b0_row3_col5" class="data row3 col5" >0.2428</td>
#       <td id="T_346b0_row3_col6" class="data row3 col6" >0.0710</td>
#       <td id="T_346b0_row3_col7" class="data row3 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_346b0_level0_row4" class="row_heading level0 row4" >huber</th>
#       <td id="T_346b0_row4_col0" class="data row4 col0" >Huber Regressor</td>
#       <td id="T_346b0_row4_col1" class="data row4 col1" >0.8546</td>
#       <td id="T_346b0_row4_col2" class="data row4 col2" >1.7787</td>
#       <td id="T_346b0_row4_col3" class="data row4 col3" >1.2621</td>
#       <td id="T_346b0_row4_col4" class="data row4 col4" >0.8357</td>
#       <td id="T_346b0_row4_col5" class="data row4 col5" >0.2302</td>
#       <td id="T_346b0_row4_col6" class="data row4 col6" >0.0654</td>
#       <td id="T_346b0_row4_col7" class="data row4 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_346b0_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_346b0_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_346b0_row5_col1" class="data row5 col1" >0.8689</td>
#       <td id="T_346b0_row5_col2" class="data row5 col2" >1.7303</td>
#       <td id="T_346b0_row5_col3" class="data row5 col3" >1.2542</td>
#       <td id="T_346b0_row5_col4" class="data row5 col4" >0.8343</td>
#       <td id="T_346b0_row5_col5" class="data row5 col5" >0.2166</td>
#       <td id="T_346b0_row5_col6" class="data row5 col6" >0.0688</td>
#       <td id="T_346b0_row5_col7" class="data row5 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_346b0_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_346b0_row6_col0" class="data row6 col0" >Random Forest Regressor</td>
#       <td id="T_346b0_row6_col1" class="data row6 col1" >0.8417</td>
#       <td id="T_346b0
# Finalising the model ...
# Transformation Pipeline and Model Successfully Saved
# Saved model file: model

# %%
model.pred()
# Out:
# Loading model file: model
# Transformation Pipeline and Model Successfully Loaded
# Output is written to the file: output.csv
