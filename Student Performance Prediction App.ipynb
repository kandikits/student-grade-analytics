# %% [markdown]
# ### Student Performance Prediction

# %% [markdown]
# Student Performance Prediction App predicts grade of a student by analysing academic and non-academic information of a concerned student
#
#  1. <b>train.csv</b> - Load data to train in this csv file
#  2. <b>pred.csv</b>  - Load data to run prediction in this csv file
#  3. <b>output.csv</b>- Writes predicted output in this file in the column <b>y_pred</b>
#
#  4. <b>TARGET_VARIABLE</b> - Set this variable to name of the feature/column to be predicted
#  5. <b>NUMERICAL_FEATURES</b> - List all feature/column that are of numeric type
#
# <b>Note:</b> Update variables under <b>Variables</b> section to configure inputs if required before running the notebook.
#
# To run notebook cell by cell, click on a cell and click <b>Run</b> button below the <b>Menu</b> bar. Or to run all cells, select <b>Cell --> Run All</b> from Menu bar.

# %% [markdown]
# #### Import library to read file and load to dataframe

# %%
import pandas as pd

# %% [markdown]
# #### Import library to run the app

# %%
import model

# %% [markdown]
# #### Variables

# %%
TARGET_VARIABLE='G3' #variable to be predicted
NUMERICAL_FEATURES=["age", "G1", "G2"] #features to be interpreted as numeric

# %% [markdown]
# Default values

# %%
INPUT_TRAIN_FILE="train.csv"
INPUT_TEST_FILE="pred.csv"
OUTPUT_PRED_FILE="output.csv"
OUTPUT_PRED="y_pred"
MODEL_FILE="model"

# %% [markdown]
# ####  Description of example data loaded
# Attributes for train.csv and test.csv (Portuguese language course) datasets:
#
# 1. school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# 2. sex - student's sex (binary: 'F' - female or 'M' - male)
# 3. age - student's age (numeric: from 15 to 22)
# 4. address - student's home address type (binary: 'U' - urban or 'R' - rural)
# 5. famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 6. Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 7. Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 8. Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 9. Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10. Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 11. reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 12. guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16. schoolsup - extra educational support (binary: yes or no)
# 17. famsup - family educational support (binary: yes or no)
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19. activities - extra-curricular activities (binary: yes or no)
# 20. nursery - attended nursery school (binary: yes or no)
# 21. higher - wants to take higher education (binary: yes or no)
# 22. internet - Internet access at home (binary: yes or no)
# 23. romantic - with a romantic relationship (binary: yes or no)
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related to the course subject, Portuguese:
#
# 31. G1 - first period grade (numeric: from 0 to 20)
# 32. G2 - second period grade (numeric: from 0 to 20)
# 33. G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# #### Preview of the data

# %%
pd.read_csv(INPUT_TRAIN_FILE)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2  G3
# 0       1     1       3         4   0  11  11
# 1       1     1       3         2   9  11  11
# 2       2     3       3         6  12  13  12
# 3       1     1       5         0  14  14  14
# 4       1     2       5         0  11  13  13
# ..    ...   ...     ...       ...  ..  ..  ..
# 644     1     2       5         4  10  11  10
# 645     1     1       1         4  15  15  16
# 646     1     1       5         6  11  12   9
# 647     3     4       2         6  10  10  10
# 648     3     4       5         4  10  11  11
#
# [649 rows x 33 columns]

# %% [markdown]
# #### Training

# %%
model.train(INPUT_TRAIN_FILE, TARGET_VARIABLE, NUMERICAL_FEATURES)
# Out:
# <style type="text/css">
# #T_e900a_ th {
#   text-align: left;
# }
# #T_e900a_row0_col0, #T_e900a_row0_col5, #T_e900a_row1_col0, #T_e900a_row1_col1, #T_e900a_row1_col2, #T_e900a_row1_col3, #T_e900a_row1_col4, #T_e900a_row1_col5, #T_e900a_row1_col6, #T_e900a_row2_col0, #T_e900a_row2_col1, #T_e900a_row2_col2, #T_e900a_row2_col3, #T_e900a_row2_col4, #T_e900a_row2_col5, #T_e900a_row2_col6, #T_e900a_row3_col0, #T_e900a_row3_col1, #T_e900a_row3_col2, #T_e900a_row3_col3, #T_e900a_row3_col4, #T_e900a_row3_col5, #T_e900a_row3_col6, #T_e900a_row4_col0, #T_e900a_row4_col1, #T_e900a_row4_col2, #T_e900a_row4_col3, #T_e900a_row4_col4, #T_e900a_row4_col6, #T_e900a_row5_col0, #T_e900a_row5_col1, #T_e900a_row5_col2, #T_e900a_row5_col3, #T_e900a_row5_col4, #T_e900a_row5_col5, #T_e900a_row5_col6, #T_e900a_row6_col0, #T_e900a_row6_col1, #T_e900a_row6_col2, #T_e900a_row6_col3, #T_e900a_row6_col4, #T_e900a_row6_col5, #T_e900a_row6_col6, #T_e900a_row7_col0, #T_e900a_row7_col1, #T_e900a_row7_col2, #T_e900a_row7_col3, #T_e900a_row7_col4, #T_e900a_row7_col5, #T_e900a_row7_col6, #T_e900a_row8_col0, #T_e900a_row8_col1, #T_e900a_row8_col2, #T_e900a_row8_col3, #T_e900a_row8_col4, #T_e900a_row8_col5, #T_e900a_row8_col6, #T_e900a_row9_col0, #T_e900a_row9_col1, #T_e900a_row9_col2, #T_e900a_row9_col3, #T_e900a_row9_col4, #T_e900a_row9_col5, #T_e900a_row9_col6, #T_e900a_row10_col0, #T_e900a_row10_col1, #T_e900a_row10_col2, #T_e900a_row10_col3, #T_e900a_row10_col4, #T_e900a_row10_col5, #T_e900a_row10_col6, #T_e900a_row11_col0, #T_e900a_row11_col1, #T_e900a_row11_col2, #T_e900a_row11_col3, #T_e900a_row11_col4, #T_e900a_row11_col5, #T_e900a_row11_col6, #T_e900a_row12_col0, #T_e900a_row12_col1, #T_e900a_row12_col2, #T_e900a_row12_col3, #T_e900a_row12_col4, #T_e900a_row12_col5, #T_e900a_row12_col6, #T_e900a_row13_col0, #T_e900a_row13_col1, #T_e900a_row13_col2, #T_e900a_row13_col3, #T_e900a_row13_col4, #T_e900a_row13_col5, #T_e900a_row13_col6, #T_e900a_row14_col0, #T_e900a_row14_col1, #T_e900a_row14_col2, #T_e900a_row14_col3, #T_e900a_row14_col4, #T_e900a_row14_col5, #T_e900a_row14_col6, #T_e900a_row15_col0, #T_e900a_row15_col1, #T_e900a_row15_col2, #T_e900a_row15_col3, #T_e900a_row15_col4, #T_e900a_row15_col5, #T_e900a_row15_col6, #T_e900a_row16_col0, #T_e900a_row16_col1, #T_e900a_row16_col2, #T_e900a_row16_col3, #T_e900a_row16_col4, #T_e900a_row16_col5, #T_e900a_row16_col6, #T_e900a_row17_col0, #T_e900a_row17_col1, #T_e900a_row17_col2, #T_e900a_row17_col3, #T_e900a_row17_col4, #T_e900a_row17_col5, #T_e900a_row17_col6 {
#   text-align: left;
# }
# #T_e900a_row0_col1, #T_e900a_row0_col2, #T_e900a_row0_col3, #T_e900a_row0_col4, #T_e900a_row0_col6, #T_e900a_row4_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e900a_row0_col7, #T_e900a_row1_col7, #T_e900a_row2_col7, #T_e900a_row3_col7, #T_e900a_row4_col7, #T_e900a_row5_col7, #T_e900a_row6_col7, #T_e900a_row7_col7, #T_e900a_row8_col7, #T_e900a_row9_col7, #T_e900a_row10_col7, #T_e900a_row11_col7, #T_e900a_row12_col7, #T_e900a_row13_col7, #T_e900a_row14_col7, #T_e900a_row16_col7, #T_e900a_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e900a_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e900a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e900a_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_e900a_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_e900a_row0_col1" class="data row0 col1" >0.7650</td>
#       <td id="T_e900a_row0_col2" class="data row0 col2" >1.6104</td>
#       <td id="T_e900a_row0_col3" class="data row0 col3" >1.2059</td>
#       <td id="T_e900a_row0_col4" class="data row0 col4" >0.8498</td>
#       <td id="T_e900a_row0_col5" class="data row0 col5" >0.2108</td>
#       <td id="T_e900a_row0_col6" class="data row0 col6" >0.0792</td>
#       <td id="T_e900a_row0_col7" class="data row0 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_e900a_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_e900a_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_e900a_row1_col1" class="data row1 col1" >0.7880</td>
#       <td id="T_e900a_row1_col2" class="data row1 col2" >1.6494</td>
#       <td id="T_e900a_row1_col3" class="data row1 col3" >1.2198</td>
#       <td id="T_e900a_row1_col4" class="data row1 col4" >0.8460</td>
#       <td id="T_e900a_row1_col5" class="data row1 col5" >0.2074</td>
#       <td id="T_e900a_row1_col6" class="data row1 col6" >0.0822</td>
#       <td id="T_e900a_row1_col7" class="data row1 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_e900a_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_e900a_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_e900a_row2_col1" class="data row2 col1" >0.7994</td>
#       <td id="T_e900a_row2_col2" class="data row2 col2" >1.6585</td>
#       <td id="T_e900a_row2_col3" class="data row2 col3" >1.2409</td>
#       <td id="T_e900a_row2_col4" class="data row2 col4" >0.8388</td>
#       <td id="T_e900a_row2_col5" class="data row2 col5" >0.2041</td>
#       <td id="T_e900a_row2_col6" class="data row2 col6" >0.0825</td>
#       <td id="T_e900a_row2_col7" class="data row2 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_e900a_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_e900a_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_e900a_row3_col1" class="data row3 col1" >0.8319</td>
#       <td id="T_e900a_row3_col2" class="data row3 col2" >1.7507</td>
#       <td id="T_e900a_row3_col3" class="data row3 col3" >1.2735</td>
#       <td id="T_e900a_row3_col4" class="data row3 col4" >0.8311</td>
#       <td id="T_e900a_row3_col5" class="data row3 col5" >0.2108</td>
#       <td id="T_e900a_row3_col6" class="data row3 col6" >0.0848</td>
#       <td id="T_e900a_row3_col7" class="data row3 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_e900a_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_e900a_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_e900a_row4_col1" class="data row4 col1" >0.8584</td>
#       <td id="T_e900a_row4_col2" class="data row4 col2" >1.7807</td>
#       <td id="T_e900a_row4_col3" class="data row4 col3" >1.2854</td>
#       <td id="T_e900a_row4_col4" class="data row4 col4" >0.8268</td>
#       <td id="T_e900a_row4_col5" class="data row4 col5" >0.2028</td>
#       <td id="T_e900a_row4_col6" class="data row4 col6" >0.0866</td>
#       <td id="T_e900a_row4_col7" class="data row4 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_e900a_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_e900a_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_e900a_row5_col1" class="data row5 col1" >0.8404</td>
#       <td id="T_e900a_row5_col2" class="data row5 col2" >1.8627</td>
#       <td id="T_e900a_row5_col3" class="data row5 col3" >1.3075</td>
#       <td id="T_e900a_row5_col4" class="data row5 col4" >0.8200</td>
#       <td id="T_e900a_row5_col5" class="data row5 col5" >0.2071</td>
#       <td id="T_e900a_row5_col6" class="data row5 col6" >0.0872</td>
#       <td id="T_e900a_row5_col7" class="data row5 col7" >0.1130</td>
#     </tr>
#     <tr>
#       <th id="T_e900a_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_e900a_row6_col0" class="data row6 col0" >Random Forest Regressor</td>
#       <td id="T_e900a_row6_col1" class="data row6 col1" >0.8316</td>
#       <td id="T_e900a_row6_col2" clas
# Finalising the model ...
# Transformation Pipeline and Model Successfully Saved
# Saved model file: model

# %% [markdown]
# #### Prediction

# %%
model.pred(INPUT_TEST_FILE)
# Out:
# Loading model file: model
# Transformation Pipeline and Model Successfully Loaded
# Output is written to the file: output.csv

# %% [markdown]
# #### Preview of the predicted data

# %%
pd.read_csv(OUTPUT_PRED_FILE)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   15       R     LE3       T     2     2    health  services
# 1      MS   F   18       U     GT3       T     1     2     other     other
# 2      GP   M   15       U     GT3       A     3     4  services     other
# 3      GP   M   15       U     GT3       T     4     4  services   teacher
# 4      GP   M   18       U     GT3       T     4     2   teacher     other
# ..    ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 60     GP   F   17       U     GT3       T     3     3   at_home     other
# 61     MS   F   16       R     GT3       T     2     2   at_home     other
# 62     MS   M   18       R     GT3       T     3     2     other     other
# 63     GP   F   15       R     GT3       T     2     2   at_home     other
# 64     GP   F   15       U     GT3       T     1     2   at_home     other
#
#     ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 y_pred
# 0   ...        1     3     1     3       4        0  11  10  11   11.0
# 1   ...        4     4     2     3       5        9   9   8   8    9.0
# 2   ...        4     4     1     1       1        0  16  16  16   16.0
# 3   ...        3     3     1     1       5        0  14  15  15   15.0
# 4   ...        3     2     1     4       5        2  15  16  16   16.0
# ..  ...      ...   ...   ...   ...     ...      ...  ..  ..  ..    ...
# 60  ...        2     5     2     5       5        2  11  12  11   12.0
# 61  ...        4     4     2     3       5        2  12  11  12   12.0
# 62  ...        5     5     5     5       5        8   9  10  11   10.0
# 63  ...        3     1     1     1       2        8  14  13  12   14.0
# 64  ...        3     2     1     1       5        6  13  12  13   13.0
#
# [65 rows x 34 columns]

# %% [markdown]
# ### Customisation

# %% [markdown]
# #### Variables

# %%
TARGET_VARIABLE='G3' #variable to be predicted
NUMERICAL_FEATURES=["age", "G1", "G2"] #features to be interpreted as numeric

# %% [markdown]
# Default values

# %%
INPUT_TRAIN_FILE="student-mat.csv"
INPUT_TEST_FILE="pred.csv"
OUTPUT_PRED_FILE="output.csv"
OUTPUT_PRED="y_pred"
MODEL_FILE="model"

# %% [markdown]
# ### Data preview

# %%
pd.read_csv(INPUT_TRAIN_FILE)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# ### Training

# %%
model.train(INPUT_TRAIN_FILE, TARGET_VARIABLE, NUMERICAL_FEATURES)
# Out:
# <style type="text/css">
# #T_8e314_ th {
#   text-align: left;
# }
# #T_8e314_row0_col0, #T_8e314_row0_col2, #T_8e314_row0_col3, #T_8e314_row0_col5, #T_8e314_row1_col0, #T_8e314_row1_col1, #T_8e314_row1_col2, #T_8e314_row1_col3, #T_8e314_row1_col5, #T_8e314_row1_col6, #T_8e314_row2_col0, #T_8e314_row2_col1, #T_8e314_row2_col2, #T_8e314_row2_col3, #T_8e314_row2_col4, #T_8e314_row2_col6, #T_8e314_row3_col0, #T_8e314_row3_col1, #T_8e314_row3_col2, #T_8e314_row3_col3, #T_8e314_row3_col4, #T_8e314_row3_col5, #T_8e314_row3_col6, #T_8e314_row4_col0, #T_8e314_row4_col1, #T_8e314_row4_col4, #T_8e314_row4_col5, #T_8e314_row4_col6, #T_8e314_row5_col0, #T_8e314_row5_col1, #T_8e314_row5_col2, #T_8e314_row5_col3, #T_8e314_row5_col4, #T_8e314_row5_col5, #T_8e314_row5_col6, #T_8e314_row6_col0, #T_8e314_row6_col1, #T_8e314_row6_col2, #T_8e314_row6_col3, #T_8e314_row6_col4, #T_8e314_row6_col5, #T_8e314_row6_col6, #T_8e314_row7_col0, #T_8e314_row7_col1, #T_8e314_row7_col2, #T_8e314_row7_col3, #T_8e314_row7_col4, #T_8e314_row7_col5, #T_8e314_row7_col6, #T_8e314_row8_col0, #T_8e314_row8_col1, #T_8e314_row8_col2, #T_8e314_row8_col3, #T_8e314_row8_col4, #T_8e314_row8_col5, #T_8e314_row8_col6, #T_8e314_row9_col0, #T_8e314_row9_col1, #T_8e314_row9_col2, #T_8e314_row9_col3, #T_8e314_row9_col4, #T_8e314_row9_col5, #T_8e314_row9_col6, #T_8e314_row10_col0, #T_8e314_row10_col1, #T_8e314_row10_col2, #T_8e314_row10_col3, #T_8e314_row10_col4, #T_8e314_row10_col5, #T_8e314_row10_col6, #T_8e314_row11_col0, #T_8e314_row11_col1, #T_8e314_row11_col2, #T_8e314_row11_col3, #T_8e314_row11_col4, #T_8e314_row11_col5, #T_8e314_row11_col6, #T_8e314_row12_col0, #T_8e314_row12_col1, #T_8e314_row12_col2, #T_8e314_row12_col3, #T_8e314_row12_col4, #T_8e314_row12_col5, #T_8e314_row12_col6, #T_8e314_row13_col0, #T_8e314_row13_col1, #T_8e314_row13_col2, #T_8e314_row13_col3, #T_8e314_row13_col4, #T_8e314_row13_col5, #T_8e314_row13_col6, #T_8e314_row14_col0, #T_8e314_row14_col1, #T_8e314_row14_col2, #T_8e314_row14_col3, #T_8e314_row14_col4, #T_8e314_row14_col5, #T_8e314_row14_col6, #T_8e314_row15_col0, #T_8e314_row15_col1, #T_8e314_row15_col2, #T_8e314_row15_col3, #T_8e314_row15_col4, #T_8e314_row15_col5, #T_8e314_row15_col6, #T_8e314_row16_col0, #T_8e314_row16_col1, #T_8e314_row16_col2, #T_8e314_row16_col3, #T_8e314_row16_col4, #T_8e314_row16_col5, #T_8e314_row16_col6, #T_8e314_row17_col0, #T_8e314_row17_col1, #T_8e314_row17_col2, #T_8e314_row17_col3, #T_8e314_row17_col4, #T_8e314_row17_col5, #T_8e314_row17_col6 {
#   text-align: left;
# }
# #T_8e314_row0_col1, #T_8e314_row0_col4, #T_8e314_row0_col6, #T_8e314_row1_col4, #T_8e314_row2_col5, #T_8e314_row4_col2, #T_8e314_row4_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8e314_row0_col7, #T_8e314_row2_col7, #T_8e314_row3_col7, #T_8e314_row4_col7, #T_8e314_row5_col7, #T_8e314_row6_col7, #T_8e314_row7_col7, #T_8e314_row8_col7, #T_8e314_row9_col7, #T_8e314_row10_col7, #T_8e314_row11_col7, #T_8e314_row13_col7, #T_8e314_row14_col7, #T_8e314_row15_col7, #T_8e314_row16_col7, #T_8e314_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8e314_row1_col7, #T_8e314_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8e314_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e314_level0_row0" class="row_heading level0 row0" >lasso</th>
#       <td id="T_8e314_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_8e314_row0_col1" class="data row0 col1" >0.9899</td>
#       <td id="T_8e314_row0_col2" class="data row0 col2" >3.2566</td>
#       <td id="T_8e314_row0_col3" class="data row0 col3" >1.7373</td>
#       <td id="T_8e314_row0_col4" class="data row0 col4" >0.8257</td>
#       <td id="T_8e314_row0_col5" class="data row0 col5" >0.4220</td>
#       <td id="T_8e314_row0_col6" class="data row0 col6" >0.0678</td>
#       <td id="T_8e314_row0_col7" class="data row0 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_8e314_level0_row1" class="row_heading level0 row1" >en</th>
#       <td id="T_8e314_row1_col0" class="data row1 col0" >Elastic Net</td>
#       <td id="T_8e314_row1_col1" class="data row1 col1" >1.0227</td>
#       <td id="T_8e314_row1_col2" class="data row1 col2" >3.2284</td>
#       <td id="T_8e314_row1_col3" class="data row1 col3" >1.7364</td>
#       <td id="T_8e314_row1_col4" class="data row1 col4" >0.8257</td>
#       <td id="T_8e314_row1_col5" class="data row1 col5" >0.4325</td>
#       <td id="T_8e314_row1_col6" class="data row1 col6" >0.0711</td>
#       <td id="T_8e314_row1_col7" class="data row1 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_8e314_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_8e314_row2_col0" class="data row2 col0" >K Neighbors Regressor</td>
#       <td id="T_8e314_row2_col1" class="data row2 col1" >1.1597</td>
#       <td id="T_8e314_row2_col2" class="data row2 col2" >3.1451</td>
#       <td id="T_8e314_row2_col3" class="data row2 col3" >1.7512</td>
#       <td id="T_8e314_row2_col4" class="data row2 col4" >0.8232</td>
#       <td id="T_8e314_row2_col5" class="data row2 col5" >0.3824</td>
#       <td id="T_8e314_row2_col6" class="data row2 col6" >0.0991</td>
#       <td id="T_8e314_row2_col7" class="data row2 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_8e314_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_8e314_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_8e314_row3_col1" class="data row3 col1" >1.1380</td>
#       <td id="T_8e314_row3_col2" class="data row3 col2" >3.4190</td>
#       <td id="T_8e314_row3_col3" class="data row3 col3" >1.7908</td>
#       <td id="T_8e314_row3_col4" class="data row3 col4" >0.8114</td>
#       <td id="T_8e314_row3_col5" class="data row3 col5" >0.4274</td>
#       <td id="T_8e314_row3_col6" class="data row3 col6" >0.0847</td>
#       <td id="T_8e314_row3_col7" class="data row3 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_8e314_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_8e314_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_8e314_row4_col1" class="data row4 col1" >1.0928</td>
#       <td id="T_8e314_row4_col2" class="data row4 col2" >3.1081</td>
#       <td id="T_8e314_row4_col3" class="data row4 col3" >1.7077</td>
#       <td id="T_8e314_row4_col4" class="data row4 col4" >0.8102</td>
#       <td id="T_8e314_row4_col5" class="data row4 col5" >0.3879</td>
#       <td id="T_8e314_row4_col6" class="data row4 col6" >0.0904</td>
#       <td id="T_8e314_row4_col7" class="data row4 col7" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_8e314_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_8e314_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_8e314_row5_col1" class="data row5 col1" >1.1563</td>
#       <td id="T_8e314_row5_col2" class="data row5 col2" >3.3740</td>
#       <td id="T_8e314_row5_col3" class="data row5 col3" >1.7919</td>
#       <td id="T_8e314_row5_col4" class="data row5 col4" >0.8067</td>
#       <td id="T_8e314_row5_col5" class="data row5 col5" >0.4240</td>
#       <td id="T_8e314_row5_col6" class="data row5 col6" >0.0912</td>
#       <td id="T_8e314_row5_col7" class="data row5 col7" >0.0850</td>
#     </tr>
#     <tr>
#       <th id="T_8e314_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_8e314_row6_col0" class="data row6 col0" >Random Forest Regressor</td>
#       <td id="T_8e314_row6_col1" class="data row6 col1" >1.0744</td>
#       <td id="T_8e314_row6_col2"
# Finalising the model ...
# Transformation Pipeline and Model Successfully Saved
# Saved model file: model

# %% [markdown]
# ### Prediction

# %%
model.pred(INPUT_TEST_FILE)
# Out:
# Loading model file: model
# Transformation Pipeline and Model Successfully Loaded
# Output is written to the file: output.csv

# %% [markdown]
# ### Preview of predicted data

# %%
pd.read_csv(OUTPUT_PRED_FILE)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   15       R     LE3       T     2     2    health  services
# 1      MS   F   18       U     GT3       T     1     2     other     other
# 2      GP   M   15       U     GT3       A     3     4  services     other
# 3      GP   M   15       U     GT3       T     4     4  services   teacher
# 4      GP   M   18       U     GT3       T     4     2   teacher     other
# ..    ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 60     GP   F   17       U     GT3       T     3     3   at_home     other
# 61     MS   F   16       R     GT3       T     2     2   at_home     other
# 62     MS   M   18       R     GT3       T     3     2     other     other
# 63     GP   F   15       R     GT3       T     2     2   at_home     other
# 64     GP   F   15       U     GT3       T     1     2   at_home     other
#
#     ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 y_pred
# 0   ...        1     3     1     3       4        0  11  10  11   10.0
# 1   ...        4     4     2     3       5        9   9   8   8    8.0
# 2   ...        4     4     1     1       1        0  16  16  16   16.0
# 3   ...        3     3     1     1       5        0  14  15  15   15.0
# 4   ...        3     2     1     4       5        2  15  16  16   16.0
# ..  ...      ...   ...   ...   ...     ...      ...  ..  ..  ..    ...
# 60  ...        2     5     2     5       5        2  11  12  11   12.0
# 61  ...        4     4     2     3       5        2  12  11  12   11.0
# 62  ...        5     5     5     5       5        8   9  10  11   10.0
# 63  ...        3     1     1     1       2        8  14  13  12   13.0
# 64  ...        3     2     1     1       5        6  13  12  13   12.0
#
# [65 rows x 34 columns]
